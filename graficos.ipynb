# %%
import sys
import paho.mqtt.client
import json
import psycopg2
import plotly.graph_objects as go
from datetime import datetime
from psycopg2 import Error
from IPython.display import clear_output
import ipywidgets as widgets
import pandas as pd
import plotly.express as px
import time



def main():
	
	global connection, cursor
	sql_query = "SELECT temp, fecha FROM tempcaracas"
	print(sql_query)
	
	data_frame = pd.read_sql(sql_query, connection)


	fig = go.FigureWidget(px.line(data_frame, x='fecha', y='temp', title='temperatura de Caracas'))
	
	while not fig.data:
		data_frame = pd.read_sql(sql_query, connection)
		fig = go.FigureWidget(px.line(data_frame, x='fecha', y='temp', title='temperatura de Caracas'))

	display(widgets.VBox([fig]))
	cont =100
	while True:
		time.sleep(2)
		data_frame = pd.read_sql(sql_query, connection)
		with fig.batch_update():
			fig.data[0].y = data_frame['temp']
			fig.data[0].x = data_frame['fecha']


		
	



try:
	connection = psycopg2.connect(user="ufwkwpgo",
								password="JC-EWjqXDxpWrUpJ7j3qIcTnmZiFRpKW",
								host="queenie.db.elephantsql.com",
								database="ufwkwpgo")
	cursor = connection.cursor()

	print("PostgreSQL server information")
	print(connection.get_dsn_parameters(), "\n")
	# Executing a SQL query
	cursor.execute("SELECT version();")
	# Fetch result
	record = cursor.fetchone()
	print("You are connected to - ", record, "\n")

	if __name__ == '__main__':
		main()


except (Exception, Error) as error:
	print("Error while connecting to PostgreSQL", error)
finally:
	if connection:
		cursor.close()
		connection.close()
		print("PostgreSQL connection is closed")
		sys.exit(0)
# Out:
# PostgreSQL server information
# {'user': 'ufwkwpgo', 'dbname': 'ufwkwpgo', 'host': 'queenie.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.11 (Ubuntu 11.11-1.pgdg20.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0, 64-bit',)
#
# SELECT temp, fecha FROM tempcaracas
# ...
#     'data': [{'hovertemplate': 'fecha=%{x}<br>temp=%{y}<extra></extra>',
#        …
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# PostgreSQL connection is closed
# Traceback (most recent call last):
#   File "<ipython-input-5-c1f9b2fc69bd>", line 62, in <module>
#     main()
#   File "<ipython-input-5-c1f9b2fc69bd>", line 34, in main
#     time.sleep(2)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import sys
import paho.mqtt.client
import json
import psycopg2
import plotly.graph_objects as go
from datetime import datetime
from psycopg2 import Error
from IPython.display import clear_output
import ipywidgets as widgets
import pandas as pd
import plotly.express as px
import time



def main():
	
	global connection, cursor
	sql_query = "SELECT temp, fecha FROM tempnevera"
	print(sql_query)

	data_frame = pd.read_sql(sql_query, connection)

	fig = go.FigureWidget(px.line(data_frame, x='fecha', y='temp', title='temperatura de Nevera'))
	while not fig.data:
		data_frame = pd.read_sql(sql_query, connection)
		fig = go.FigureWidget(px.line(data_frame, x='fecha', y='temp', title='temperatura de Nevera'))
	
	display(widgets.VBox([fig]))
	cont =100
	while True:
		time.sleep(2)
		data_frame = pd.read_sql(sql_query, connection)
		if not fig.data:
			print("la cague")
			fig = go.FigureWidget(px.line(data_frame, x='fecha', y='temp', title='temperatura de Nevera'))

		else:
			with fig.batch_update():
				fig.data[0].y = data_frame['temp']
				fig.data[0].x = data_frame['fecha']


		
	



try:
	connection = psycopg2.connect(user="ufwkwpgo",
								password="JC-EWjqXDxpWrUpJ7j3qIcTnmZiFRpKW",
								host="queenie.db.elephantsql.com",
								database="ufwkwpgo")
	cursor = connection.cursor()

	print("PostgreSQL server information")
	print(connection.get_dsn_parameters(), "\n")
	# Executing a SQL query
	cursor.execute("SELECT version();")
	# Fetch result
	record = cursor.fetchone()
	print("You are connected to - ", record, "\n")

	if __name__ == '__main__':
		main()


except (Exception, Error) as error:
	print("Error while connecting to PostgreSQL", error)
finally:
	if connection:
		cursor.close()
		connection.close()
		print("PostgreSQL connection is closed")
		sys.exit(0)
# Out:
# PostgreSQL server information
# {'user': 'ufwkwpgo', 'dbname': 'ufwkwpgo', 'host': 'queenie.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.11 (Ubuntu 11.11-1.pgdg20.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0, 64-bit',)
#
# SELECT temp, fecha FROM tempnevera
# ...
#     'data': [{'hovertemplate': 'fecha=%{x}<br>temp=%{y}<extra></extra>',
#        …
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# PostgreSQL connection is closed
# Traceback (most recent call last):
#   File "<ipython-input-11-efbc70a57958>", line 65, in <module>
#     main()
#   File "<ipython-input-11-efbc70a57958>", line 32, in main
#     time.sleep(2)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import sys
import paho.mqtt.client
import json
import psycopg2
import plotly.graph_objects as go
from datetime import datetime
from psycopg2 import Error
from IPython.display import clear_output
import ipywidgets as widgets
import pandas as pd
import plotly.express as px
import time



def main():
	
	global connection, cursor
	sql_query = "SELECT hielo, fecha FROM hielonevera"
	print(sql_query)
	
	data_frame = pd.read_sql(sql_query, connection)


	fig = go.FigureWidget(px.line(data_frame, x='fecha', y='hielo', title='Hielo de la Nevera'))
	
	while not fig.data:
		data_frame = pd.read_sql(sql_query, connection)
		fig = go.FigureWidget(px.line(data_frame, x='fecha', y='hielo', title='Hielo de la Nevera'))

	display(widgets.VBox([fig]))
	cont =100
	while True:
		time.sleep(2)
		data_frame = pd.read_sql(sql_query, connection)
		with fig.batch_update():
			fig.data[0].y = data_frame['hielo']
			fig.data[0].x = data_frame['fecha']


		
	



try:
	connection = psycopg2.connect(user="ufwkwpgo",
								password="JC-EWjqXDxpWrUpJ7j3qIcTnmZiFRpKW",
								host="queenie.db.elephantsql.com",
								database="ufwkwpgo")
	cursor = connection.cursor()

	print("PostgreSQL server information")
	print(connection.get_dsn_parameters(), "\n")
	# Executing a SQL query
	cursor.execute("SELECT version();")
	# Fetch result
	record = cursor.fetchone()
	print("You are connected to - ", record, "\n")

	if __name__ == '__main__':
		main()


except (Exception, Error) as error:
	print("Error while connecting to PostgreSQL", error)
finally:
	if connection:
		cursor.close()
		connection.close()
		print("PostgreSQL connection is closed")
		sys.exit(0)
# Out:
# PostgreSQL server information
# {'user': 'ufwkwpgo', 'dbname': 'ufwkwpgo', 'host': 'queenie.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.11 (Ubuntu 11.11-1.pgdg20.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0, 64-bit',)
#
# SELECT hielo, fecha FROM hielonevera
# ...
#     'data': [{'hovertemplate': 'fecha=%{x}<br>hielo=%{y}<extra></extra>',
#       …
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# PostgreSQL connection is closed
# Traceback (most recent call last):
#   File "<ipython-input-1-316f100bfdc6>", line 62, in <module>
#     main()
#   File "<ipython-input-1-316f100bfdc6>", line 34, in main
#     time.sleep(2)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import sys
import paho.mqtt.client
import json
import psycopg2
import plotly.graph_objects as go
from datetime import datetime
from psycopg2 import Error
from IPython.display import clear_output
import ipywidgets as widgets
import pandas as pd
import plotly.express as px
import time



def main():
	
	global connection, cursor
	sql_query = "SELECT temp, fecha FROM olla"
	print(sql_query)
	
	data_frame = pd.read_sql(sql_query, connection)


	fig = go.FigureWidget(px.line(data_frame, x='fecha', y='temp', title='Temperatura de la Olla'))
	
	while not fig.data:
		data_frame = pd.read_sql(sql_query, connection)
		fig = go.FigureWidget(px.line(data_frame, x='fecha', y='temp', title='Temperatura de la Olla'))

	display(widgets.VBox([fig]))
	cont =100
	while True:
		time.sleep(2)
		data_frame = pd.read_sql(sql_query, connection)
		with fig.batch_update():
			fig.data[0].y = data_frame['temp']
			fig.data[0].x = data_frame['fecha']


		
	



try:
	connection = psycopg2.connect(user="ufwkwpgo",
								password="JC-EWjqXDxpWrUpJ7j3qIcTnmZiFRpKW",
								host="queenie.db.elephantsql.com",
								database="ufwkwpgo")
	cursor = connection.cursor()

	print("PostgreSQL server information")
	print(connection.get_dsn_parameters(), "\n")
	# Executing a SQL query
	cursor.execute("SELECT version();")
	# Fetch result
	record = cursor.fetchone()
	print("You are connected to - ", record, "\n")

	if __name__ == '__main__':
		main()


except (Exception, Error) as error:
	print("Error while connecting to PostgreSQL", error)
finally:
	if connection:
		cursor.close()
		connection.close()
		print("PostgreSQL connection is closed")
		sys.exit(0)
# Out:
# PostgreSQL server information
# {'user': 'ufwkwpgo', 'dbname': 'ufwkwpgo', 'host': 'queenie.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.11 (Ubuntu 11.11-1.pgdg20.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0, 64-bit',)
#
# SELECT temp, fecha FROM olla
# ...
#     'data': [{'hovertemplate': 'fecha=%{x}<br>temp=%{y}<extra></extra>',
#        …
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# PostgreSQL connection is closed
# Traceback (most recent call last):
#   File "<ipython-input-1-515c6715f407>", line 62, in <module>
#     main()
#   File "<ipython-input-1-515c6715f407>", line 34, in main
#     time.sleep(2)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import sys
import paho.mqtt.client
import json
import psycopg2
import plotly.graph_objects as go
from datetime import datetime
from psycopg2 import Error
from IPython.display import clear_output
import ipywidgets as widgets
import pandas as pd
import plotly.express as px
import time



def main():
	
	global connection, cursor
	sql_query = "SELECT cant_agua, fecha FROM tanqueagua"
	print(sql_query)
	
	data_frame = pd.read_sql(sql_query, connection)


	fig = go.FigureWidget(px.line(data_frame, x='fecha', y='cant_agua', title='Agua en el Tanque'))
	
	while not fig.data:
		data_frame = pd.read_sql(sql_query, connection)
		fig = go.FigureWidget(px.line(data_frame, x='fecha', y='cant_agua', title='Agua en el Tanque'))

	display(widgets.VBox([fig]))
	cont =100
	while True:
		time.sleep(2)
		data_frame = pd.read_sql(sql_query, connection)
		with fig.batch_update():
			fig.data[0].y = data_frame['cant_agua']
			fig.data[0].x = data_frame['fecha']


		
	



try:
	connection = psycopg2.connect(user="ufwkwpgo",
								password="JC-EWjqXDxpWrUpJ7j3qIcTnmZiFRpKW",
								host="queenie.db.elephantsql.com",
								database="ufwkwpgo")
	cursor = connection.cursor()

	print("PostgreSQL server information")
	print(connection.get_dsn_parameters(), "\n")
	# Executing a SQL query
	cursor.execute("SELECT version();")
	# Fetch result
	record = cursor.fetchone()
	print("You are connected to - ", record, "\n")

	if __name__ == '__main__':
		main()


except (Exception, Error) as error:
	print("Error while connecting to PostgreSQL", error)
finally:
	if connection:
		cursor.close()
		connection.close()
		print("PostgreSQL connection is closed")
		sys.exit(0)
# Out:
# PostgreSQL server information
# {'user': 'ufwkwpgo', 'dbname': 'ufwkwpgo', 'host': 'queenie.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.11 (Ubuntu 11.11-1.pgdg20.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0, 64-bit',)
#
# SELECT cant_agua, fecha FROM tanqueagua
# ...
#     'data': [{'hovertemplate': 'fecha=%{x}<br>cant_agua=%{y}<extra></extra>',
#   …
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# PostgreSQL connection is closed
# Traceback (most recent call last):
#   File "<ipython-input-6-4aed5b57a18b>", line 62, in <module>
#     main()
#   File "<ipython-input-6-4aed5b57a18b>", line 35, in main
#     data_frame = pd.read_sql(sql_query, connection)
# ...

# %%
import sys
import paho.mqtt.client
import json
import psycopg2
import plotly.graph_objects as go
from datetime import datetime
from psycopg2 import Error
from IPython.display import clear_output
import ipywidgets as widgets
import pandas as pd
import plotly.express as px
import time



def main():
	
	global connection, cursor
	sql_query = "SELECT cant_personas, fecha FROM contsala"
	print(sql_query)
	
	data_frame = pd.read_sql(sql_query, connection)


	fig = go.FigureWidget(px.line(data_frame, x='fecha', y='cant_personas', title='Cantidad de Personas en la Sala'))
	
	while not fig.data:
		data_frame = pd.read_sql(sql_query, connection)
		fig = go.FigureWidget(px.line(data_frame, x='fecha', y='cant_personas', title='Cantidad de Personas en la Sala'))

	display(widgets.VBox([fig]))
	cont =100
	while True:
		time.sleep(2)
		data_frame = pd.read_sql(sql_query, connection)
		with fig.batch_update():
			fig.data[0].y = data_frame['cant_personas']
			fig.data[0].x = data_frame['fecha']


		
	



try:
	connection = psycopg2.connect(user="ufwkwpgo",
								password="JC-EWjqXDxpWrUpJ7j3qIcTnmZiFRpKW",
								host="queenie.db.elephantsql.com",
								database="ufwkwpgo")
	cursor = connection.cursor()

	print("PostgreSQL server information")
	print(connection.get_dsn_parameters(), "\n")
	# Executing a SQL query
	cursor.execute("SELECT version();")
	# Fetch result
	record = cursor.fetchone()
	print("You are connected to - ", record, "\n")

	if __name__ == '__main__':
		main()


except (Exception, Error) as error:
	print("Error while connecting to PostgreSQL", error)
finally:
	if connection:
		cursor.close()
		connection.close()
		print("PostgreSQL connection is closed")
		sys.exit(0)
# Out:
# PostgreSQL server information
# {'user': 'ufwkwpgo', 'dbname': 'ufwkwpgo', 'host': 'queenie.db.elephantsql.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.11 (Ubuntu 11.11-1.pgdg20.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0, 64-bit',)
#
# SELECT cant_personas, fecha FROM contsala
# ...
#     'data': [{'hovertemplate': 'fecha=%{x}<br>cant_personas=%{y}<extra></extra>'…
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# PostgreSQL connection is closed
# Traceback (most recent call last):
#   File "<ipython-input-1-ea98f2770753>", line 62, in <module>
#     main()
#   File "<ipython-input-1-ea98f2770753>", line 34, in main
#     time.sleep(2)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ...
